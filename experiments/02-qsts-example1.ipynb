# %%
import os
import requests
LOCAL_HOST = os.environ.get("LOCAL_HOST")
SERVER_PY_PORT = os.environ.get("SERVER_PY_PORT")

# %% [markdown]
# Note: Start Docker in a separate terminal window so that Ray remains accessible for running multiple workers.
# ```sh
# make start
# ```
# To see available targets and their descriptions in the Makefile, run `make.

# %%
url = f"http://{LOCAL_HOST}:{SERVER_PY_PORT}/run-qsts"
response = requests.get(url)
response.raise_for_status()
data = response.json()
print(data)
# Out:
# {'status': 'Daily power flow run completed successfully', 'rows': 96}
